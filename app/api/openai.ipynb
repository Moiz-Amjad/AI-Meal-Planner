# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path=".env.local")
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "I weigh 182 pounds and am 5'10. I want to lose weight. Please recommend me a wweekly meal plan to lose 5 pounds in a month. I work out 3 days a week with weightlifting training. Please return answer in JSON format"}
  ]
)

# %%
message = completion.choices[0].message.content
print(message)
# Out:
# Here’s a weekly meal plan formatted in JSON for you, targeting a weight loss of 5 pounds in a month while considering your weightlifting routine. This meal plan includes balanced meals and snacks geared towards weight loss, focusing on whole foods and proper portions.
#
# ```json
# {
#   "mealPlan": {
#     "day1": {
#       "breakfast": {
#         "item": "Oatmeal with berries and a tablespoon of almond butter",
#         "calories": 350
#       },
#       "snack": {
#         "item": "Greek yogurt with honey",
#         "calories": 150
#       },
#       "lunch": {
#         "item": "Grilled chicken salad with mixed greens, veggies, and vinaigrette",
#         "calories": 400
#       },
#       "snack": {
#         "item": "Carrot sticks with hummus",
#         "calories": 100
#       },
#       "dinner": {
#         "item": "Baked salmon with quinoa and steamed broccoli",
#         "calories": 500
#       }
#     },
#     "day2": {
#       "breakfast": {
# ...
